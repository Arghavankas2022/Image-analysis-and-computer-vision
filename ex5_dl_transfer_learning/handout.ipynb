# %% [markdown]
# # IACV Exercise 5: Transfer Learning
#
# In this exercise, you will again tackle the image classification task, as in exercise 4.
# Given an input RGB image with resolution `(32, 32, 3)`, you need to predict which of the 10 input classes it belongs to.
# However, unlike in exercise 4, you have access to limited training data in `training.h5`.
# In fact, you only have `210` samples per class, which are separated into training, validation, and test sets of ratio `7:1:2` for ease of use.
# You can use these three sets of data for your development.
#
# Fortunately, you have access to a pre-trained network which has been trained on large amounts of data to classify 5 out of 10 input classes.
# That is, the pre-trained network obtains a classification accuracy of around 95% for 5 of the classes, while the remaining classes are not defined at all.
# The pretrained parameters are stored in `ckpt/resnet4five.pt` and the loading process explained below.
#
# Your task is to either adapt this model, or train a new network from scratch which can classify all 10 classes.
# Similar to exercise 4, we will use the [PyTorch](https://https://pytorch.org/) deep learning framework in this exercise.
#
# **Evaluation Criteria**
#
# Your algorithm will be evaluated using classification accuracy, which is the proportion of images with the correct predicted label.
# The final EvaluationScore is obtained as the classification accuracy over all test samples, over all 10 classes.
# The real test data used for evaluation has 1000 images without labels and can be found in `test.h5`
#
# **Rules**
#
# Throughout this project, you are **not allowed to use any other dataset and/or pre-trained model other than the given ones**.
# You are allowed to use any other techniques you have learned in the course, including but not limited to
# *data augmentation, early stopping, and transfer learning*.

# %%
# These two lines ensure that we always import the latest version of a package
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
from matplotlib import pyplot as plt


import os
import sys
import shutil
from pathlib import Path

import torch
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
iacv_path = 'MyDrive/IACV/ex5_dl_transfer_learning' # TODO set this

env_path = Path('/content/drive/') / iacv_path
# Add the handout folder to python paths
if env_path not in sys.path:
    sys.path.append(str(env_path))

# %% [markdown]
# ## Enabeling GPU on CoLab
# For this exercise you might want to use a GPU.
# Even the small ResNet we provide runs more than 25 times faster on CoLabs free GPU compared to CoLabs CPUs.
#
# In the CoLab menu, go to `Runtime` -> `Change Runtime Type` and select `T4 GPU` as harware accelerator.
#
# Note that this is free! You will not need to pay anything to use this service!

# %%
# With PyTorch you can check if a GPU is available as follows:
print(f"Is a CUDA capable GPU available? {torch.cuda.is_available()}")

# Note: CUDA is the platform developed by NVIDIA for their GPUs
# Out:
# Is a CUDA capable GPU available? True

# %% [markdown]
# ## Mapping from 5 to 10 classes
#
# Define a mapping from 5 to 10 classes because the indices do not match, such as `classes[0]` is `Airplane` while `classes5[0]` is `Cat`

# %%
# Mapping from 5 to 10 classes

# Classes for the pretrained dataset
classes5 = ["Cat", "Deer", "Frog", "Ship", "Truck"]

# Actual classes
classes = ["Airplane", "Automobile", "Bird", "Cat", "Deer",
           "Dog", "Frog", "Horse", "Ship", "Truck"]

# Converting numpy arrays for indexing
classes5 = np.array(classes5)
classes = np.array(classes)

# Mapping from 5 classes to 10 classes for evaluation
map5to10 = [np.where(classes==class_)[0][0] for class_ in classes5]
map5to10 = np.array(map5to10)
print("Mapping array is:", map5to10)
# Out:
# Mapping array is: [3 4 6 8 9]

# %%
# Example usage

# Random predictions by 5
preds5 = np.random.randint(5, size=7, dtype=int)

# Predicted classes
print("Actual Predictions:        ", classes5[preds5])

# Wrong mapping from 5 to 10 classes
print("Wrongly-mapped Predictions:", classes[preds5])

# Correct mapping from 5 to 10 classes
print("Correct-mapped Predictions:", classes[map5to10[preds5]])
# Out:
# Actual Predictions:         ['Deer' 'Truck' 'Deer' 'Deer' 'Frog' 'Deer' 'Frog']
# Wrongly-mapped Predictions: ['Automobile' 'Deer' 'Automobile' 'Automobile' 'Bird' 'Automobile' 'Bird']
# Correct-mapped Predictions: ['Deer' 'Truck' 'Deer' 'Deer' 'Frog' 'Deer' 'Frog']

# %% [markdown]
# ## Create dataloaders
#
# We have implemented the basic data handling.
# You might want to check out the file `dataset.py` nonetheless.
# In case you want to apply data augmentations during training, etc...

# %%
from dataset import get_datasets_from_h5, get_loaders_from_datasets

# Get the datasets
data_path = env_path / 'data'
train_dataset, val_dataset, test_dataset = get_datasets_from_h5(data_path / 'training.h5')

# Construct the dataloaders
batch_size = 24
train_loader, val_loader, test_loader = get_loaders_from_datasets(
    train_dataset, val_dataset, test_dataset, batch_size
)

# Print the sizes of the datasets
print(f"The dataset contains {train_dataset.num_classes} classes.")
print(f"Number of images in each dataset: Training={len(train_dataset)}, ",
      f"Validation={len(val_dataset)}, Test={len(test_dataset)}")
# Out:
# The dataset contains 10 classes.
# Number of images in each dataset: Training=1470,  Validation=210, Test=420

# %% [markdown]
# ## Visualize training images

# %%
from utils import show_images

dataiter = iter(train_loader)
images, labels = next(dataiter)

show_images(images[:6], classes[labels[:6]])

# %% [markdown]
# ## Load pre-trained model
#
# As mentioned before, you have access to parameters of a pre-trained model `resnet4five.pt`, which is a standard ResNet18 model and has been trained to classify images into 5 classes ("Cat", "Deer", "Frog", "Ship", "Truck"), using larger dataset. It achieves accuracy of higher than 90% for these classes.

# %%
from model import generate_resnet

# Path to load the model from
load_path = env_path / 'ckpt' / 'resnet4five.pt'

# Device to train on
device = "cuda" if torch.cuda.is_available() else "cpu"

# Create the model with 5 output classes
model = generate_resnet(num_classes=5)

# Next we load the pre-trained weights, and set it to the model we created
model.load_state_dict(torch.load(load_path, map_location=device, weights_only=True))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Next, we can test the pre-trained model on the dataset.
# Check out the file `evaluation.py` to see how the model is used to make a prediction.
# A very similar code will be used to create your prediction at the end of this file.

# %%
from evaluation import evaluate_model
from utils import show_class_accs

# Evaluate the model
test_accuracy = evaluate_model(model, test_loader, device=device, mapping=map5to10)
print(f"Test accuracy with pretrained model: {test_accuracy:.3f}")

# Classwise accuracies
test_class_accs = evaluate_model(
    model, test_loader, device=device, mapping=map5to10, classwise=True
)

show_class_accs(test_class_accs, classes, title="Test")
# Out:
# Test accuracy with pretrained model: 0.476

# %% [markdown]
# As expected, we see the the pre-trained model obtains good performance on the 5 out of 10 classes which it has been trained for. However, it cannot handle the other 5 *unseen* classes, and thus obtains a low overall classification accuracy. Your task is to adapt this pre-trained model such that it obtains better overall classification accuracy than iacvbasline.

# %% [markdown]
# ## Your Solution
#
# You can write your own implementation here.
# You can change the custom functions given according to your needs.

# %%
from pathlib import Path
import torch
import numpy as np
import shutil
from model import generate_resnet
from training import train_model, freeze_all_layers, unfreeze_layers, count_trainable
from dataset import (
    get_datasets_from_h5,
    get_loaders_from_datasets,
    get_test_loader,
)
env_path = Path("/content/drive/MyDrive/IACV/ex5_dl_transfer_learning")
device = "cuda" if torch.cuda.is_available() else "cpu"
training_h5 = env_path / "data" / "training.h5"
test_h5     = env_path / "data" / "test.h5"
ckpt_5class  = env_path / "ckpt" / "resnet4five.pt"
ckpt_10class = env_path / "ckpt" / "resnet10_from5.pt"
batch_size = 5
num_epochs = 100
# ---------------------------------------------------------------------
# LOAD TRAIN + VAL FROM training.h5
# ---------------------------------------------------------------------
train_dataset, val_dataset, _ = get_datasets_from_h5(training_h5)
train_loader, val_loader, _ = get_loaders_from_datasets(
    train_dataset, val_dataset, None, batch_size=batch_size
)
# ---------------------------------------------------------------------
# LOAD TEST FROM test.h5
# ---------------------------------------------------------------------
test_loader = get_test_loader(test_h5)
# ---------------------------------------------------------------------
# BUILD 10-CLASS MODEL + LOAD 5-CLASS PRETRAIN
# ---------------------------------------------------------------------
model = generate_resnet(num_classes=10).to(device)
pretrained = torch.load(ckpt_5class, map_location=device)
model_state = model.state_dict()
copied = 0
for k, v in pretrained.items():
  if k in model_state and model_state[k].shape == v.shape:
        model_state[k] = v
        copied += 1
model.load_state_dict(model_state)
print(f"Copied {copied} layers from pretrained model.")
# OPTIONAL: freeze/unfreeze
# freeze_all_layers(model)
# unfreeze_layers(model.layer4)
# unfreeze_layers(model.fc)
print("Trainable params:", count_trainable(model))
# ---------------------------------------------------------------------
# OPTIMIZER + SCHEDULER
# ---------------------------------------------------------------------
optimizer = torch.optim.SGD(
    [p for p in model.parameters() if p.requires_grad],
    lr=1e-2,
    momentum=0.9,
    weight_decay=1e-4,
)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    patience=3,
    factor=0.5,
    verbose=True,
)
# ---------------------------------------------------------------------
# TRAIN
# ---------------------------------------------------------------------
history = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    num_epochs=num_epochs,
    optimizer=optimizer,
    device=device,
    scheduler=scheduler,
    save_path=str(ckpt_10class),
    early_stopping=False,
    patience=7,
)
# ---------------------------------------------------------------------
# LOAD BEST MODEL FOR INFERENCE
# ---------------------------------------------------------------------
print("Loading best checkpoint...")
model.load_state_dict(torch.load(ckpt_10class, map_location=device))
model.eval()
# Out:
# Copied 120 layers from pretrained model.
# Trainable params: 11173962
# [Epoch 1/100] Train Loss: 1.3733 | Train Acc: 0.5170 || Val Loss: 1.0052 | Val Acc: 0.6476 | Time: 4.8s
# [Epoch 2/100] Train Loss: 1.0381 | Train Acc: 0.6122 || Val Loss: 0.8399 | Val Acc: 0.6810 | Time: 4.7s
# [Epoch 3/100] Train Loss: 0.9669 | Train Acc: 0.6374 || Val Loss: 0.9296 | Val Acc: 0.6619 | Time: 4.5s
# [Epoch 4/100] Train Loss: 0.9106 | Train Acc: 0.6701 || Val Loss: 0.7757 | Val Acc: 0.6952 | Time: 5.8s
# [Epoch 5/100] Train Loss: 0.8408 | Train Acc: 0.6871 || Val Loss: 0.7598 | Val Acc: 0.7143 | Time: 4.6s
# [Epoch 6/100] Train Loss: 0.8170 | Train Acc: 0.7054 || Val Loss: 0.7583 | Val Acc: 0.7190 | Time: 4.6s
# [Epoch 7/100] Train Loss: 0.7762 | Train Acc: 0.7143 || Val Loss: 0.7750 | Val Acc: 0.7000 | Time: 4.8s
# [Epoch 8/100] Train Loss: 0.7375 | Train Acc: 0.7408 || Val Loss: 0.8231 | Val Acc: 0.7286 | Time: 4.8s
# [Epoch 9/100] Train Loss: 0.7052 | Train Acc: 0.7483 || Val Loss: 0.6821 | Val Acc: 0.7190 | Time: 4.6s
# [Epoch 10/100] Train Loss: 0.6526 | Train Acc: 0.7673 || Val Loss: 0.7449 | Val Acc: 0.7333 | Time: 5.7s
# [Epoch 11/100] Train Loss: 0.6483 | Train Acc: 0.7626 || Val Loss: 0.7254 | Val Acc: 0.7476 | Time: 4.7s
# [Epoch 12/100] Train Loss: 0.6089 | Train Acc: 0.7816 || Val Loss: 0.7111 | Val Acc: 0.7286 | Time: 4.7s
# [Epoch 13/100] Train Loss: 0.5976 | Train Acc: 0.7857 || Val Loss: 0.6824 | Val Acc: 0.7381 | Time: 4.8s
# [Epoch 14/100] Train Loss: 0.5370 | Train Acc: 0.8136 || Val Loss: 0.6904 | Val Acc: 0.7286 | Time: 4.6s
# [Epoch 15/100] Train Loss: 0.5257 | Train Acc: 0.8041 || Val Loss: 0.6882 | Val Acc: 0.7524 | Time: 5.1s
# [Epoch 16/100] Train Loss: 0.5400 | Train Acc: 0.8136 || Val Loss: 0.6841 | Val Acc: 0.7571 | Time: 4.8s
# [Epoch 17/100] Train Loss: 0.4956 | Train Acc: 0.8286 || Val Loss: 0.6763 | Val Acc: 0.7571 | Time: 4.6s
# [Epoch 18/100] Train Loss: 0.4982 | Train Acc: 0.8306 || Val Loss: 0.6748 | Val Acc: 0.7476 | Time: 5.8s
# [Epoch 19/100] Train Loss: 0.4909 | Train Acc: 0.8320 || Val Loss: 0.7090 | Val Acc: 0.7333 | Time: 4.7s
# [Epoch 20/100] Train Loss: 0.4758 | Train Acc: 0.8435 || Val Loss: 0.6786 | Val Acc: 0.7381 | Time: 4.8s
# [Epoch 21/100] Train Loss: 0.4638 | Train Acc: 0.8401 || Val Loss: 0.7102 | Val Acc: 0.7333 | Time: 4.9s
# [Epoch 22/100] Train Loss: 0.4618 | Train Acc: 0.8401 || Val Loss: 0.7128 | Val Acc: 0.7286 | Time: 4.7s
# [Epoch 23/100] Train Loss: 0.4275 | Train Acc: 0.8571 || Val Loss: 0.7101 | Val Acc: 0.7286 | Time: 4.9s
# [Epoch 24/100] Train Loss: 0.4321 | Train Acc: 0.8463 || Val Loss: 0.6830 | Val Acc: 0.7333 | Time: 4.8s
# [Epoch 25/100] Train Loss: 0.4247 | Train Acc: 0.8578 || Val Loss: 0.6717 | Val Acc: 0.7571 | Time: 4.6s
# [Epoch 26/100] Train Loss: 0.4112 | Train Acc: 0.8680 || Val Loss: 0.6998 | Val Acc: 0.7476 | Time: 4.9s
# [Epoch 27/100] Train Loss: 0.4364 | Train Acc: 0.8517 || Val Loss: 0.6909 | Val Acc: 0.7524 | Time: 4.6s
# [Epoch 28/100] Train Loss: 0.4354 | Train Acc: 0.8544 || Val Loss: 0.7005 | Val Acc: 0.7333 | Time: 4.6s
# [Epoch 29/100] Train Loss: 0.4264 | Train Acc: 0.8639 || Val Loss: 0.6635 | Val Acc: 0.7429 | Time: 4.9s
# [Epoch 30/100] Train Loss: 0.4009 | Train Acc: 0.8762 || Val Loss: 0.7047 | Val Acc: 0.7619 | Time: 4.7s
# [Epoch 31/100] Train Loss: 0.3871 | Train Acc: 0.8639 || Val Loss: 0.6862 | Val Acc: 0.7524 | Time: 4.7s
# [Epoch 32/100] Train Loss: 0.3827 | Train Acc: 0.8837 || Val Loss: 0.7034 | Val Acc: 0.7476 | Time: 4.8s
# [Epoch 33/100] Train Loss: 0.4184 | Train Acc: 0.8660 || Val Loss: 0.7050 | Val Acc: 0.7429 | Time: 4.7s
# [Epoch 34/100] Train Loss: 0.3718 | Train Acc: 0.8769 || Val Loss: 0.6959 | Val Acc: 0.7476 | Time: 4.8s
# [Epoch 35/100] Train Loss: 0.3709 | Train Acc: 0.8803 || Val Loss: 0.7144 | Val Acc: 0.7476 | Time: 4.8s
# [Epoch 36/100] Train Loss: 0.3676 | Train Acc: 0.8823 || Val Loss: 0.7244 | Val Acc: 0.7381 | Time: 4.6s
# [Epoch 37/100] Train Loss: 0.3728 | Train Acc: 0.8748 || Val Loss: 0.7093 | Val Acc: 0.7476 | Time: 4.9s
# [Epoch 38/100] Train Loss: 0.3655 | Train Acc: 0.8796 || Val Loss: 0.7434 | Val Acc: 0.7286 | Time: 4.6s
# [Epoch 39/100] Train Loss: 0.3676 | Train Acc: 0.8789 || Val Loss: 0.6993 | Val Acc: 0.7524 | Time: 4.6s
# [Epoch 40/100] Train Loss: 0.3612 | Train Acc: 0.8898 || Val Loss: 0.6884 | Val Acc: 0.7381 | Time: 4.9s
# [Epoch 41/100] Train Loss: 0.3760 | Train Acc: 0.8850 || Val Loss: 0.7428 | Val Acc: 0.7571 | Time: 4.7s
# [Epoch 42/100] Train Loss: 0.3877 | Train Acc: 0.8748 || Val Loss: 0.6855 | Val Acc: 0.7524 | Time: 4.8s
# [Epoch 43/100] Train Loss: 0.3659 | Train Acc: 0.8850 || Val Loss: 0.7267 | Val Acc: 0.7524 | Time: 4.8s
# [Epoch 44/100] Train Loss: 0.3642 | Train Acc: 0.8803 || Val Loss: 0.6942 | Val Acc: 0.7619 | Time: 4.6s
# [Epoch 45/100] Train Loss: 0.3672 | Train Acc: 0.8816 || Val Loss: 0.7019 | Val Acc: 0.7429 | Time: 4.8s
# [Epoch 46/100] Train Loss: 0.3837 | Train Acc: 0.8701 || Val Loss: 0.7428 | Val Acc: 0.7524 | Time: 4.8s
# [Epoch 47/100] Train Loss: 0.3611 | Train Acc: 0.8864 || Val Loss: 0.7105 | Val Acc: 0.7429 | Time: 4.6s
# [Epoch 48/100] Train Loss: 0.3456 | Train Acc: 0.8912 || Val Loss: 0.7054 | Val Acc: 0.7571 | Time: 4.9s
# [Epoch 49/100] Train Loss: 0.3636 | Train Acc: 0.8796 || Val Loss: 0.7349 | Val Acc: 0.7524 | Time: 4.7s
# [Epoch 50/100] Train Loss: 0.3744 | Train Acc: 0.8782 || Val Loss: 0.6876 | Val Acc: 0.7714 | Time: 4.8s
# [Epoch 51/100] Train Loss: 0.3580 | Train Acc: 0.8898 || Val Loss: 0.7213 | Val Acc: 0.7524 | Time: 4.9s
# [Epoch 52/100] Train Loss: 0.3732 | Train Acc: 0.8694 || Val Loss: 0.7248 | Val Acc: 0.7286 | Time: 4.6s
# [Epoch 53/100] Train Loss: 0.3365 | Train Acc: 0.8939 || Val Loss: 0.6882 | Val Acc: 0.7571 | Time: 4.9s
# [Epoch 54/100] Train Loss: 0.3682 | Train Acc: 0.8816 || Val Loss: 0.7188 | Val Acc: 0.7476 | Time: 4.9s
# [Epoch 55/100] Train Loss: 0.3513 | Train Acc: 0.8871 || Val Loss: 0.7173 | Val Acc: 0.7381 | Time: 4.6s
# [Epoch 56/100] Train Loss: 0.3484 | Train Acc: 0.8980 || Val Loss: 0.7220 | Val Acc: 0.7333 | Time: 4.8s
# [Epoch 57/100] Train Loss: 0.3661 | Train Acc: 0.8878 || Val Loss: 0.7277 | Val Acc: 0.7381 | Time: 4.8s
# [Epoch 58/100] Train Loss: 0.3623 | Train Acc: 0.8803 || Val Loss: 0.7197 | Val Acc: 0.7524 | Time: 4.6s
# [Epoch 59/100] Train Loss: 0.3698 | Train Acc: 0.8735 || Val Loss: 0.7152 | Val Acc: 0.7381 | Time: 4.9s
# [Epoch 60/100] Train Loss: 0.3387 | Train Acc: 0.8912 || Val Loss: 0.6909 | Val Acc: 0.7476 | Time: 4.7s
# [Epoch 61/100] Train Loss: 0.3671 | Train Acc: 0.8823 || Val Loss: 0.6863 | Val Acc: 0.7571 | Time: 4.6s
# [Epoch 62/100] Train Loss: 0.3667 | Train Acc: 0.8857 || Val Loss: 0.7130 | Val Acc: 0.7476 | Time: 4.9s
# [Epoch 63/100] Train Loss: 0.3527 | Train Acc: 0.8844 || Val Loss: 0.7325 | Val Acc: 0.7381 | Time: 4.7s
# [Epoch 64/100] Train Loss: 0.3594 | Train Acc: 0.8755 || Val Loss: 0.7269 | Val Acc: 0.7286 | Time: 4.7s
# [Epoch 65/100] Train Loss: 0.3598 | Train Acc: 0.8864 || Val Loss: 0.6998 | Val Acc: 0.7476 | Time: 4.9s
# [Epoch 66/100] Train Loss: 0.3520 | Train Acc: 0.8830 || Val Loss: 0.7314 | Val Acc: 0.7429 | Time: 4.6s
# [Epoch 67/100] Train Loss: 0.3754 | Train Acc: 0.8782 || Val Loss: 0.7042 | Val Acc: 0.7476 | Time: 4.8s
# [Epoch 68/100] Train Loss: 0.3475 | Train Acc: 0.8871 || Val Loss: 0.7167 | Val Acc: 0.7429 | Time: 4.8s
# [Epoch 69/100] Train Loss: 0.3644 | Train Acc: 0.8816 || Val Loss: 0.7093 | Val Acc: 0.7571 | Time: 4.6s
# [Epoch 70/100] Train Loss: 0.3577 | Train Acc: 0.8837 || Val Loss: 0.7200 | Val Acc: 0.7333 | Time: 4.8s
# [Epoch 71/100] Train Loss: 0.3608 | Train Acc: 0.8878 || Val Loss: 0.7027 | Val Acc: 0.7429 | Time: 4.7s
# [Epoch 72/100] Train Loss: 0.3565 | Train Acc: 0.8891 || Val Loss: 0.6961 | Val Acc: 0.7429 | Time: 4.6s
# [Epoch 73/100] Train Loss: 0.3524 | Train Acc: 0.8918 || Val Loss: 0.7000 | Val Acc: 0.7429 | Time: 4.9s
# [Epoch 74/100] Train Loss: 0.3771 | Train Acc: 0.8803 || Val Loss: 0.7145 | Val Acc: 0.7333 | Time: 4.6s
# [Epoch 75/100] Train Loss: 0.3662 | Train Acc: 0.8857 || Val Loss: 0.7069 | Val Acc: 0.7429 | Time: 4.6s
# [Epoch 76/100] Train Loss: 0.3528 | Train Acc: 0.8891 || Val Loss: 0.7343 | Val Acc: 0.7381 | Time: 4.9s
# [Epoch 77/100] Train Loss: 0.3433 | Train Acc: 0.8864 || Val Loss: 0.7016 | Val Acc: 0.7429 | Time: 4.6s
# [Epoch 78/100] Train Loss: 0.3708 | Train Acc: 0.8823 || Val Loss: 0.6891 | Val Acc: 0.7476 | Time: 4.7s
# [Epoch 79/100] Train Loss: 0.3596 | Train Acc: 0.8850 || Val Loss: 0.7120 | Val Acc: 0.7381 | Time: 4.8s
# [Epoch 80/100] Train Loss: 0.3509 | Train Acc: 0.8891 || Val Loss: 0.6928 | Val Acc: 0.7524 | Time: 4.7s
# [Epoch 81/100] Train Loss: 0.3562 | Train Acc: 0.8946 || Val Loss: 0.7393 | Val Acc: 0.7571 | Time: 4.8s
# [Epoch 82/100] Train Loss: 0.3701 | Train Acc: 0.8810 || Val Loss: 0.7456 | Val Acc: 0.7476 | Time: 4.7s
# [Epoch 83/100] Train Loss: 0.3487 | Train Acc: 0.8918 || Val Loss: 0.7198 | Val Acc: 0.7571 | Time: 4.6s
# [Epoch 84/100] Train Loss: 0.3590 | Train Acc: 0.8714 || Val Loss: 0.6951 | Val Acc: 0.7667 | Time: 4.9s
# [Epoch 85/100] Train Loss: 0.3461 | Train Acc: 0.8864 || Val Loss: 0.7185 | Val Acc: 0.7429 | Time: 4.6s
# [Epoch 86/100] Train Loss: 0.3693 | Train Acc: 0.8782 || Val Loss: 0.7181 | Val Acc: 0.7429 | Time: 4.7s
# [Epoch 87/100] Train Loss: 0.3938 | Train Acc: 0.8687 || Val Loss: 0.7007 | Val Acc: 0.7476 | Time: 4.9s
# [Epoch 88/100] Train Loss: 0.3628 | Train Acc: 0.8789 || Val Loss: 0.7285 | Val Acc: 0.7381 | Time: 4.6s
# [Epoch 89/100] Train Loss: 0.3589 | Train Acc: 0.8844 || Val Loss: 0.7177 | Val Acc: 0.7476 | Time: 4.7s
# [Epoch 90/100] Train Loss: 0.3623 | Train Acc: 0.8898 || Val Loss: 0.7088 | Val Acc: 0.7286 | Time: 4.9s
# [Epoch 91/100] Train Loss: 0.3351 | Train Acc: 0.8918 || Val Loss: 0.6969 | Val Acc: 0.7429 | Time: 4.6s
# [Epoch 92/100] Train Loss: 0.3561 | Train Acc: 0.8816 || Val Loss: 0.6893 | Val Acc: 0.7571 | Time: 4.8s
# [Epoch 93/100] Train Loss: 0.3417 | Train Acc: 0.8905 || Val Loss: 0.6917 | Val Acc: 0.7381 | Time: 4.9s
# [Epoch 94/100] Train Loss: 0.3553 | Train Acc: 0.8871 || Val Loss: 0.7115 | Val Acc: 0.7476 | Time: 4.6s
# [Epoch 95/100] Train Loss: 0.3492 | Train Acc: 0.8932 || Val Loss: 0.7309 | Val Acc: 0.7524 | Time: 4.8s
# [Epoch 96/100] Train Loss: 0.3624 | Train Acc: 0.8728 || Val Loss: 0.6927 | Val Acc: 0.7571 | Time: 4.7s
# [Epoch 97/100] Train Loss: 0.3529 | Train Acc: 0.9000 || Val Loss: 0.7377 | Val Acc: 0.7381 | Time: 4.6s
# [Epoch 98/100] Train Loss: 0.3903 | Train Acc: 0.8735 || Val Loss: 0.7360 | Val Acc: 0.7333 | Time: 4.9s
# [Epoch 99/100] Train Loss: 0.3769 | Train Acc: 0.8762 || Val Loss: 0.7477 | Val Acc: 0.7476 | Time: 4.6s
# [Epoch 100/100] Train Loss: 0.3688 | Train Acc: 0.8871 || Val Loss: 0.7133 | Val Acc: 0.7429 | Time: 4.6s
# Training finished. Best val acc: 0.7714285714285715
# Loading best checkpoint...
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ## Generating the final submission
#
# When you are happy with your network, you can run the next cell to generate your network predictions on the test set, which will be stored in the submission directory on your Google Drive.
# Download the submission folder (without renaming) as a zip, and upload it to the evaluation server to obtain the scores on the test set.

# %%
from dataset import get_test_loader

test_h5_path = env_path / 'data' / 'test.h5'

submission_path = env_path / 'submission'
submission_path.mkdir(exist_ok=True)

# Choose device to run inference
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load test dataset and dataloader
test_loader = get_test_loader(test_h5_path)

# Predictions to store
predictions = list()

# Set to evaluation mode
model.eval()

# Iterate over the test set
with torch.no_grad():
    for images, _ in test_loader:
        images = images.to(device)
        outputs = model(images)
        # Get the predictions
        _, preds = torch.max(outputs, 1)
        preds = preds.cpu()
        predictions.extend(preds.tolist())

# Save the outputs (do not change the name)
np.savetxt(submission_path / 'labels.csv', predictions, fmt="%d")

# Save the relevant files (do not change the name)
shutil.copyfile(env_path / 'model.py', submission_path / 'model.py')
shutil.copyfile(env_path / 'dataset.py', submission_path / 'dataset.py')
shutil.copyfile(env_path / 'training.py', submission_path / 'training.py')
shutil.copyfile(env_path / 'handout.ipynb', submission_path / 'handout.ipynb')
# Out:
# PosixPath('/content/drive/MyDrive/IACV/ex5_dl_transfer_learning/submission/handout.ipynb')
